# %%
import numpy as np
data = np.genfromtxt('/Users/telmo/projects/ghostborders/belgium_dist_time.csv', names=['dist', 'time'], skip_header=1, delimiter=',')

# %%
# %matplotlib inline

import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# the histogram of the data
n, bins, patches = plt.hist(data['dist'], 50)

plt.xlabel('Distance')
plt.ylabel('Count')
plt.title('Graph link distance histogram')
#plt.axis([40, 160, 0, 0.03])
plt.grid(True)

plt.show()

# %%
# the histogram of the data
n, bins, patches = plt.hist(data['time'], 50)

plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Graph link time histogram')
plt.grid(True)

plt.show()

# %%
#plt.scatter(data['dist'], data['time'], alpha=0.5, s=1.)
plt.hexbin(data['dist'], data['time'], xscale='log', yscale='log')
plt.show()

# %%
import numpy as np
data = np.genfromtxt('/Users/telmo/projects/ghostborders/belgium-percentiles/metrics2.csv', names=['dist', 'time', 'modularity','ncomms'], skip_header=1, delimiter=',')

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.scatter(data['dist'], data['ncomms'])
plt.show()
# Out:
# /Users/telmo/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
import numpy as np
data = np.genfromtxt('/Users/telmo/projects/ghostborders/belgium-percentiles/borders.csv', names=['x1', 'y1', 'x2', 'y2', 'weight', 'mean_dist', 'std_dist', 'max_dist'], skip_header=1, delimiter=',')

# %%
# %matplotlib inline

plt.scatter(data['mean_dist'], data['std_dist'], alpha=.1)
plt.show()
# Out:
# /Users/telmo/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
import numpy as np
data = np.genfromtxt('/Users/telmo/projects/ghostborders/entropy_paris.csv', names=['per', 'entropy'], skip_header=1, delimiter=',')

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.scatter(data['per'], data['entropy'])
plt.show()
# Out:
# /Users/telmo/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
